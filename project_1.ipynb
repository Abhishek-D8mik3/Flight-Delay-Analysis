# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek-D8mik3/Flight-Delay-Analysis/blob/main/project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import datetime as dt

pd.set_option('display.max_columns', None)

# %%
df= pd.read_csv('Airline_Delay_Cause.csv')
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2023      8      9E  Endeavor Air Inc.     ABE
# 1  2023      8      9E  Endeavor Air Inc.     ABY
# 2  2023      8      9E  Endeavor Air Inc.     AEX
# 3  2023      8      9E  Endeavor Air Inc.     AGS
# 4  2023      8      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0       13.0
# 1             Albany, GA: Southwest Georgia Regional         62.0       10.0
# 2           Alexandria, LA: Alexandria International         62.0       10.0
# 3        Augusta, GA: Augusta Regional at Bush Field         66.0       12.0
# 4                   Albany, NY: Albany International         92.0       22.0
#
#    carrier_ct  weather_ct  nas_ct  security_ct  late_aircraft_ct  \
# 0        2.25        1.60    3.16          0.0              5.99
# 1        1.97        0.04    0.57          0.0              7.42
# 2        2.73        1.18    1.80          0.0              4.28
# 3        3.69        2.27    4.47          0.0              1.57
# 4        7.76        0.00    2.96          0.0             11.28
#
#    arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0            2.0           1.0     1375.0           71.0          761.0
# 1            0.0           1.0      799.0          218.0            1.0
# 2            1.0           0.0      766.0           56.0          188.0
# 3            1.0           1.0     1397.0          471.0          320.0
# 4            2.0           0.0     1530.0          628.0            0.0
#
#    nas_delay  security_delay  late_aircraft_delay
# 0      118.0             0.0                425.0
# 1       62.0             0.0                518.0
# 2       78.0             0.0                444.0
# 3      388.0             0.0                218.0
# 4      134.0             0.0                768.0

# %%
df
# Out:
#         year  month carrier            carrier_name airport  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE
# 1       2023      8      9E       Endeavor Air Inc.     ABY
# 2       2023      8      9E       Endeavor Air Inc.     AEX
# 3       2023      8      9E       Endeavor Air Inc.     AGS
# 4       2023      8      9E       Endeavor Air Inc.     ALB
# ...      ...    ...     ...                     ...     ...
# 171661  2013      8      YV      Mesa Airlines Inc.     TRI
# 171662  2013      8      YV      Mesa Airlines Inc.     YUM
# 171663  2013      8      YV      Mesa Airlines Inc.     SLC
# 171664  2013      8      DL    Delta Air Lines Inc.     SBN
# 171665  2013      8      F9  Frontier Airlines Inc.     MTJ
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0
# 1                  Albany, GA: Southwest Georgia Regional         62.0
# 2                Alexandria, LA: Alexandria International         62.0
# 3             Augusta, GA: Augusta Regional at Bush Field         66.0
# 4                        Albany, NY: Albany International         92.0
# ...                                                   ...          ...
# 171661     Bristol/Johnson City/Kingsport, TN: Tri Cities          7.0
# 171662             Yuma, AZ: Yuma MCAS/Yuma International          2.0
# 171663   Salt Lake City, UT: Salt Lake City International          2.0
# 171664           South Bend, IN: South Bend International          1.0
# 171665              Montrose/Delta, CO: Montrose Regional          1.0
#
#         arr_del15  carrier_ct  weather_ct  nas_ct  security_ct  \
# 0            13.0        2.25        1.60    3.16          0.0
# 1            10.0        1.97        0.04    0.57          0.0
# 2            10.0        2.73        1.18    1.80          0.0
# 3            12.0        3.69        2.27    4.47          0.0
# 4            22.0        7.76        0.00    2.96          0.0
# ...           ...         ...         ...     ...          ...
# 171661        1.0        0.78        0.00    0.22          0.0
# 171662        1.0        0.00        0.00    0.00          0.0
# 171663        0.0        0.00        0.00    0.00          0.0
# 171664        1.0        1.00        0.00    0.00          0.0
# 171665        0.0        0.00        0.00    0.00          0.0
#
#         late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0                   5.99            2.0           1.0     1375.0
# 1                   7.42            0.0           1.0      799.0
# 2                   4.28            1.0           0.0      766.0
# 3                   1.57            1.0           1.0     1397.0
# 4                  11.28            2.0           0.0     1530.0
# ...                  ...            ...           ...        ...
# 171661              0.00            0.0           0.0       23.0
# 171662              1.00            0.0           0.0       17.0
# 171663              0.00            0.0           0.0        0.0
# 171664              0.00            0.0           0.0       18.0
# 171665              0.00            0.0           0.0        0.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0                71.0          761.0      118.0             0.0
# 1               218.0            1.0       62.0             0.0
# 2                56.0          188.0       78.0             0.0
# 3               471.0          320.0      388.0             0.0
# 4               628.0            0.0      134.0             0.0
# ...               ...            ...        ...             ...
# 171661           18.0            0.0        5.0             0.0
# 171662            0.0            0.0        0.0             0.0
# 171663            0.0            0.0        0.0             0.0
# 171664           18.0            0.0        0.0             0.0
# 171665            0.0            0.0        0.0             0.0
#
#         late_aircraft_delay
# 0                     425.0
# 1                     518.0
# 2                     444.0
# 3                     218.0
# 4                     768.0
# ...                     ...
# 171661                  0.0
# 171662                 17.0
# 171663                  0.0
# 171664                  0.0
# 171665                  0.0
#
# [171666 rows x 21 columns]

# %%
df.info()
df.isnull().sum()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171666 entries, 0 to 171665
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 171666 non-null  int64
#  1   month                171666 non-null  int64
#  2   carrier              171666 non-null  object
#  3   carrier_name         171666 non-null  object
#  4   airport              171666 non-null  object
#  5   airport_name         171666 non-null  object
#  6   arr_flights          171426 non-null  float64
#  7   arr_del15            171223 non-null  float64
#  8   carrier_ct           171426 non-null  float64
#  9   weather_ct           171426 non-null  float64
#  10  nas_ct               171426 non-null  float64
#  11  security_ct          171426 non-null  float64
#  12  late_aircraft_ct     171426 non-null  float64
#  13  arr_cancelled        171426 non-null  float64
#  14  arr_diverted         171426 non-null  float64
#  15  arr_delay            171426 non-null  float64
#  16  carrier_delay        171426 non-null  float64
#  17  weather_delay        171426 non-null  float64
#  18  nas_delay            171426 non-null  float64
#  19  security_delay       171426 non-null  float64
#  20  late_aircraft_delay  171426 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 27.5+ MB
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name',
#        'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# year                     0
# month                    0
# carrier                  0
# carrier_name             0
# airport                  0
# airport_name             0
# arr_flights            240
# arr_del15              443
# carrier_ct             240
# weather_ct             240
# nas_ct                 240
# security_ct            240
# late_aircraft_ct       240
# arr_cancelled          240
# arr_diverted           240
# arr_delay              240
# carrier_delay          240
# weather_delay          240
# nas_delay              240
# security_delay         240
# late_aircraft_delay    240
# dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name',
#        'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         year  month carrier            carrier_name airport  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE
# 1       2023      8      9E       Endeavor Air Inc.     ABY
# 2       2023      8      9E       Endeavor Air Inc.     AEX
# 3       2023      8      9E       Endeavor Air Inc.     AGS
# 4       2023      8      9E       Endeavor Air Inc.     ALB
# ...      ...    ...     ...                     ...     ...
# 171661  2013      8      YV      Mesa Airlines Inc.     TRI
# 171662  2013      8      YV      Mesa Airlines Inc.     YUM
# 171663  2013      8      YV      Mesa Airlines Inc.     SLC
# 171664  2013      8      DL    Delta Air Lines Inc.     SBN
# 171665  2013      8      F9  Frontier Airlines Inc.     MTJ
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0
# 1                  Albany, GA: Southwest Georgia Regional         62.0
# 2                Alexandria, LA: Alexandria International         62.0
# 3             Augusta, GA: Augusta Regional at Bush Field         66.0
# 4                        Albany, NY: Albany International         92.0
# ...                                                   ...          ...
# 171661     Bristol/Johnson City/Kingsport, TN: Tri Cities          7.0
# 171662             Yuma, AZ: Yuma MCAS/Yuma International          2.0
# 171663   Salt Lake City, UT: Salt Lake City International          2.0
# 171664           South Bend, IN: South Bend International          1.0
# 171665              Montrose/Delta, CO: Montrose Regional          1.0
#
#         arr_del15  carrier_ct  weather_ct  nas_ct  security_ct  \
# 0            13.0        2.25        1.60    3.16          0.0
# 1            10.0        1.97        0.04    0.57          0.0
# 2            10.0        2.73        1.18    1.80          0.0
# 3            12.0        3.69        2.27    4.47          0.0
# 4            22.0        7.76        0.00    2.96          0.0
# ...           ...         ...         ...     ...          ...
# 171661        1.0        0.78        0.00    0.22          0.0
# 171662        1.0        0.00        0.00    0.00          0.0
# 171663        0.0        0.00        0.00    0.00          0.0
# 171664        1.0        1.00        0.00    0.00          0.0
# 171665        0.0        0.00        0.00    0.00          0.0
#
#         late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0                   5.99            2.0           1.0     1375.0
# 1                   7.42            0.0           1.0      799.0
# 2                   4.28            1.0           0.0      766.0
# 3                   1.57            1.0           1.0     1397.0
# 4                  11.28            2.0           0.0     1530.0
# ...                  ...            ...           ...        ...
# 171661              0.00            0.0           0.0       23.0
# 171662              1.00            0.0           0.0       17.0
# 171663              0.00            0.0           0.0        0.0
# 171664              0.00            0.0           0.0       18.0
# 171665              0.00            0.0           0.0        0.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0                71.0          761.0      118.0             0.0
# 1               218.0            1.0       62.0             0.0
# 2                56.0          188.0       78.0             0.0
# 3               471.0          320.0      388.0             0.0
# 4               628.0            0.0      134.0             0.0
# ...               ...            ...        ...             ...
# 171661           18.0            0.0        5.0             0.0
# 171662            0.0            0.0        0.0             0.0
# 171663            0.0            0.0        0.0             0.0
# 171664           18.0            0.0        0.0             0.0
# 171665            0.0            0.0        0.0             0.0
#
#         late_aircraft_delay
# 0                     425.0
# 1                     518.0
# 2                     444.0
# 3                     218.0
# 4                     768.0
# ...                     ...
# 171661                  0.0
# 171662                 17.0
# 171663                  0.0
# 171664                  0.0
# 171665                  0.0
#
# [171223 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64

# %%
df.fillna(df.select_dtypes(include=['number']).mean(), inplace=True)

# %%
df
# Out:
#         year  month carrier            carrier_name airport  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE
# 1       2023      8      9E       Endeavor Air Inc.     ABY
# 2       2023      8      9E       Endeavor Air Inc.     AEX
# 3       2023      8      9E       Endeavor Air Inc.     AGS
# 4       2023      8      9E       Endeavor Air Inc.     ALB
# ...      ...    ...     ...                     ...     ...
# 171661  2013      8      YV      Mesa Airlines Inc.     TRI
# 171662  2013      8      YV      Mesa Airlines Inc.     YUM
# 171663  2013      8      YV      Mesa Airlines Inc.     SLC
# 171664  2013      8      DL    Delta Air Lines Inc.     SBN
# 171665  2013      8      F9  Frontier Airlines Inc.     MTJ
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0
# 1                  Albany, GA: Southwest Georgia Regional         62.0
# 2                Alexandria, LA: Alexandria International         62.0
# 3             Augusta, GA: Augusta Regional at Bush Field         66.0
# 4                        Albany, NY: Albany International         92.0
# ...                                                   ...          ...
# 171661     Bristol/Johnson City/Kingsport, TN: Tri Cities          7.0
# 171662             Yuma, AZ: Yuma MCAS/Yuma International          2.0
# 171663   Salt Lake City, UT: Salt Lake City International          2.0
# 171664           South Bend, IN: South Bend International          1.0
# 171665              Montrose/Delta, CO: Montrose Regional          1.0
#
#         arr_del15  carrier_ct  weather_ct  nas_ct  security_ct  \
# 0            13.0        2.25        1.60    3.16          0.0
# 1            10.0        1.97        0.04    0.57          0.0
# 2            10.0        2.73        1.18    1.80          0.0
# 3            12.0        3.69        2.27    4.47          0.0
# 4            22.0        7.76        0.00    2.96          0.0
# ...           ...         ...         ...     ...          ...
# 171661        1.0        0.78        0.00    0.22          0.0
# 171662        1.0        0.00        0.00    0.00          0.0
# 171663        0.0        0.00        0.00    0.00          0.0
# 171664        1.0        1.00        0.00    0.00          0.0
# 171665        0.0        0.00        0.00    0.00          0.0
#
#         late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0                   5.99            2.0           1.0     1375.0
# 1                   7.42            0.0           1.0      799.0
# 2                   4.28            1.0           0.0      766.0
# 3                   1.57            1.0           1.0     1397.0
# 4                  11.28            2.0           0.0     1530.0
# ...                  ...            ...           ...        ...
# 171661              0.00            0.0           0.0       23.0
# 171662              1.00            0.0           0.0       17.0
# 171663              0.00            0.0           0.0        0.0
# 171664              0.00            0.0           0.0       18.0
# 171665              0.00            0.0           0.0        0.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0                71.0          761.0      118.0             0.0
# 1               218.0            1.0       62.0             0.0
# 2                56.0          188.0       78.0             0.0
# 3               471.0          320.0      388.0             0.0
# 4               628.0            0.0      134.0             0.0
# ...               ...            ...        ...             ...
# 171661           18.0            0.0        5.0             0.0
# 171662            0.0            0.0        0.0             0.0
# 171663            0.0            0.0        0.0             0.0
# 171664           18.0            0.0        0.0             0.0
# 171665            0.0            0.0        0.0             0.0
#
#         late_aircraft_delay
# 0                     425.0
# 1                     518.0
# 2                     444.0
# 3                     218.0
# 4                     768.0
# ...                     ...
# 171661                  0.0
# 171662                 17.0
# 171663                  0.0
# 171664                  0.0
# 171665                  0.0
#
# [171223 rows x 21 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                 year          month    arr_flights      arr_del15  \
# count  171223.000000  171223.000000  171223.000000  171223.000000
# mean     2018.549739       6.495284     362.946427      66.434387
# std         2.891314       3.441753     993.408638     179.540694
# min      2013.000000       1.000000       1.000000       0.000000
# 25%      2016.000000       3.000000      50.000000       6.000000
# 50%      2019.000000       7.000000     101.000000      17.000000
# 75%      2021.000000       9.000000     250.000000      47.000000
# max      2023.000000      12.000000   21977.000000    4176.000000
#
#           carrier_ct     weather_ct         nas_ct    security_ct  \
# count  171223.000000  171223.000000  171223.000000  171223.000000
# mean       20.821272       2.253015      19.404125       0.157283
# std        50.339895       7.318176      61.708181       0.717809
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.170000       0.000000       1.000000       0.000000
# 50%         6.410000       0.400000       3.930000       0.000000
# 75%        17.300000       1.860000      11.730000       0.000000
# max      1293.910000     266.420000    1884.420000      58.690000
#
#        late_aircraft_ct  arr_cancelled  arr_diverted      arr_delay  \
# count     171223.000000  171223.000000  171223.00000  171223.000000
# mean          23.798736       7.527686       0.86430    4244.513617
# std           72.431750      43.676378       3.77497   12625.199210
# min            0.000000       0.000000       0.00000       0.000000
# 25%            1.240000       0.000000       0.00000     336.000000
# 50%            5.000000       1.000000       0.00000    1020.000000
# 75%           15.280000       4.000000       1.00000    2888.500000
# max         2069.070000    4951.000000     197.00000  438783.000000
#
#        carrier_delay  weather_delay      nas_delay  security_delay  \
# count  171223.000000  171223.000000  171223.000000   171223.000000
# mean     1438.889034     222.827365     921.743218        7.391478
# std      4217.885488     821.537321    3425.391326       41.803971
# min         0.000000       0.000000       0.000000        0.000000
# 25%       111.000000       0.000000      35.000000        0.000000
# 50%       375.000000      18.000000     147.000000        0.000000
# 75%      1110.000000     146.000000     478.000000        0.000000
# max    196944.000000   31960.000000  112018.000000     3760.000000
#
#        late_aircraft_delay
# count        171223.000000
# mean           1653.658299
# std            5224.663092
# min               0.000000
# 25%              66.000000
# 50%             321.000000
# 75%            1072.000000
# max          227959.000000

# %%
#Which Airline have the most delays?

plt.figure(figsize=(12,6))
airline_delays =df.groupby("carrier_name")["arr_del15"].sum().sort_values(ascending=False)
sns.barplot(y=airline_delays.index, x=airline_delays.values, palette= "coolwarm")
plt.title("Number of Delayed Flights by Airline")
plt.xlabel("Count of Delayed Flights")
plt.ylabel("Airline")
plt.show()
# Out:
# <ipython-input-20-f54501d37dff>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=airline_delays.index, x=airline_delays.values, palette= "coolwarm")

# %%
#most punctual airline

most_punctual_airline = df.groupby("carrier_name")["arr_del15"].sum().sort_values(ascending=True).index[0]
print("The most punctual airline (least delay) is :", most_punctual_airline)
# Out:
# The most punctual airline (least delay) is : AirTran Airways Corporation

# %%
print(df.columns)
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name',
#        'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='object')

# %%
delay_types = df[["carrier_delay", "late_aircraft_delay", "nas_delay"]].sum()

plt.figure(figsize=(8,5))
sns.barplot(x= delay_types.index, y= delay_types.values, palette = "coolwarm")
plt.title("Total Delay Conribution By Type")
plt.xlabel("DelayType")
plt.ylabel("Total Delay(minutes)")
plt.show()
# Out:
# <ipython-input-23-47b11dc69e44>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= delay_types.index, y= delay_types.values, palette = "coolwarm")

# %%
#What Are the Main Reasons for Flight Delays?
delay_causes = df[["carrier_delay", "weather_delay","nas_delay", "security_delay","late_aircraft_delay" ]].sum()

plt.figure(figsize=(9,6))
sns.barplot(x=delay_causes.index, y= delay_causes.values, palette= "coolwarm")
plt.title("Main Reason for Flight Delays")
plt.xlabel("Delay Type")
plt.ylabel("Total Delay (minutes)")
plt.show()
# Out:
# <ipython-input-27-604207e3f299>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=delay_causes.index, y= delay_causes.values, palette= "coolwarm")

# %%
#Which Airports Experience the Most Delays?

airport_delays = df.groupby("airport_name")["arr_del15"].sum().sort_values(ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(y=airport_delays.index[:10], x= airport_delays.values[:10], palette= "coolwarm")
plt.title("Top 10 Airport with the Most Flight Delays")
plt.xlabel("Total Delayed Flights")
plt.ylabel("Airport")
plt.show()
# Out:
# <ipython-input-30-67a71dd84e37>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=airport_delays.index[:10], x= airport_delays.values[:10], palette= "coolwarm")

# %%
print(df.columns)
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name',
#        'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='object')

# %%
#Which month has the highest number of flight delays?

month_delay = df.groupby("month")["arr_del15"].sum().sort_values(ascending= False)

plt.figure(figsize=(10,5))
sns.barplot(x= month_delay.index, y=month_delay.values, palette= "coolwarm")
plt.title("Flight Delays by Month")
plt.xlabel("Month")
plt.ylabel("Total Delayed Flights")
plt.show()
# Out:
# <ipython-input-34-44124a1814ff>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= month_delay.index, y=month_delay.values, palette= "coolwarm")
